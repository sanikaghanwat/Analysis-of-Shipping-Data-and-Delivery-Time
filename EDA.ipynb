# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\GHANWAT\Downloads\Train.csv")
df
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %% [markdown]
# In this data 4 collumns are categorical.

# %%
df.describe()
# Out:
#                 ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count  10999.00000         10999.000000     10999.000000         10999.000000
# mean    5500.00000             4.054459         2.990545           210.196836
# std     3175.28214             1.141490         1.413603            48.063272
# min        1.00000             2.000000         1.000000            96.000000
# 25%     2750.50000             3.000000         2.000000           169.000000
# 50%     5500.00000             4.000000         3.000000           214.000000
# 75%     8249.50000             5.000000         4.000000           251.000000
# max    10999.00000             7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# count     10999.000000      10999.000000   10999.000000         10999.000000
# mean          3.567597         13.373216    3634.016729             0.596691
# ...

# %% [markdown]
# In this data 10999 rows and 12 columnass and max weight of the product is up too 8,000  the max discount on the product is 65%.

# %%
df.shape
# Out:
# (10999, 12)

# %%
df.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %% [markdown]
# In this data their is no null value

# %% [markdown]
# # EDA

# %% [markdown]
# #  Univariate analysis

# %%
c=["green"]
df.value_counts("Warehouse_block").plot(kind="bar",color=c)
# Out:
# <Axes: xlabel='Warehouse_block'>

# %% [markdown]
# #

# %% [markdown]
# max products are shipping from "F" Warehouse block

# %%
df.value_counts("Mode_of_Shipment").plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# more products are shipping by the ship then road and flight

# %%
sns.histplot(data=df,x="Cost_of_the_Product",kde=True, bins= 10,color="purple")
# Out:
# <Axes: xlabel='Cost_of_the_Product', ylabel='Count'>

# %% [markdown]
# the highest cost of the product is in betw. aprox 250 to 270

# %%
sns.histplot(data=df,x="Prior_purchases",kde=True, bins= 10,color="red")
# Out:
# <Axes: xlabel='Prior_purchases', ylabel='Count'>

# %% [markdown]
# after  certain time the delivery of the product is dec

# %%
df.value_counts("Reached.on.Time_Y.N").plot(kind="pie")
plt.legend({"YES":1,"NO":0,})

# %% [markdown]
# maximum delivery are successful.

# %%
fig, ax = plt.subplots(1,3,figsize=(20,5))
plt.suptitle("Shipment",fontsize=16)
ax1=plt.subplot(1,3,2)
sns.boxplot(data=df,x="Customer_care_calls",color='pink')

ax2=plt.subplot(1,3,1)
sns.boxplot(data=df,x="Prior_purchases",color='green')

ax3=plt.subplot(1,3,3)
sns.boxplot(data=df,x="Weight_in_gms",color='red')
# Out:
# <Axes: xlabel='Weight_in_gms'>

# %% [markdown]
# # Bivariate / multivariate analysis

# %%
sns.histplot(data=df,x="Weight_in_gms",hue="Reached.on.Time_Y.N",bins=10)
# Out:
# <Axes: xlabel='Weight_in_gms', ylabel='Count'>

# %%
mode = sns.FacetGrid(df, col="Mode_of_Shipment", hue="Reached.on.Time_Y.N")
mode.map(sns.histplot, "Weight_in_gms")
mode.add_legend()
# Out:
# C:\Users\GHANWAT\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
mode = sns.FacetGrid(df, col="Product_importance", hue="Reached.on.Time_Y.N")
mode.map(sns.histplot, "Weight_in_gms")
mode.add_legend()
# Out:
# C:\Users\GHANWAT\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.barplot(data=df,x="Gender",y="Prior_purchases")
plt.grid()

# %%
sns.barplot(data=df,y="Cost_of_the_Product",x="Product_importance",hue="Reached.on.Time_Y.N")
plt.grid()

# %%
sns.barplot(data=df,y="Cost_of_the_Product",x="Mode_of_Shipment")
plt.grid()

# %%
sns.barplot(data=df,y="Discount_offered",x="Mode_of_Shipment")
plt.grid()
